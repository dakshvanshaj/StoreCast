# %% [markdown]
# #### Objective Phase: Time-Series Signal Processing & Feature Architecture
# - We will move to the third objective from `04_time_series_analysis.ipynb`.
#
# #### 3. **Signal Extraction & Stationarity Testing**
#
# Action: Decompose the raw sales signal into its core components (Trend, Seasonality, Residuals) using seasonal decomposition.
#
# Action: Apply the Augmented Dickey-Fuller (ADF) test to the residuals to definitively prove the extracted components successfully captured the non-stationary movement.

# %% [markdown]
# How you choose Additive/Multiplicative: Previously we looked at the Variance. The holiday spikes were not getting taller as the baseline grows(i.e seasonal effect is not proportional to trend), hence we would use Multiplicative. If they had stayed the same size, we would have used Additive.
#
# - But, Because we decided to apply log1p transformation in `05_time_series_analysis.ipynb`, we mathematically forced the data to become Additive. ( $\log(A \times B) = \log(A) + \log(B)$).
#
# - Now you must use **Additive decomposition**.
